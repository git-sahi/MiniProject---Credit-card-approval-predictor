# %% [markdown]
# ## **Visualizing And Analyszing The Data**

# %% [markdown]
# **Importing The Libraries**

# %%
# %pip install notebook ipykernel
# Out:
# Requirement already satisfied: notebook in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (7.5.5)
# Requirement already satisfied: ipykernel in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (7.2.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from notebook) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from notebook) (2.28.0)
# Requirement already satisfied: jupyterlab<4.6,>=4.5.6 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from notebook) (4.5.6)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from notebook) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from notebook) (6.5.5)
# Requirement already satisfied: anyio>=3.1.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.12.1)
# Requirement already satisfied: argon2-cffi>=21.1 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.9.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.17.0)
# Requirement already satisfied: nbformat>=5.3.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.10.4)
# Requirement already satisfied: packaging>=22.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (26.0)
# Requirement already satisfied: prometheus-client>=0.9 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.24.1)
# Requirement already satisfied: pywinpty>=2.0.1 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.0.3)
# Requirement already satisfied: pyzmq>=24 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.9.0)
# Requirement already satisfied: async-lru>=1.0.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyterlab<4.6,>=4.5.6->notebook) (2.2.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyterlab<4.6,>=4.5.6->notebook) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyterlab<4.6,>=4.5.6->notebook) (2.3.0)
# Requirement already satisfied: setuptools>=41.1.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyterlab<4.6,>=4.5.6->notebook) (82.0.1)
# Requirement already satisfied: certifi in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.6->notebook) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.6->notebook) (1.0.9)
# Requirement already satisfied: idna in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.6->notebook) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.6->notebook) (0.16.0)
# Requirement already satisfied: babel>=2.10 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (0.13.0)
# Requirement already satisfied: jsonschema>=4.18.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (4.26.0)
# Requirement already satisfied: requests>=2.31 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (2.32.5)
# Requirement already satisfied: comm>=0.1.1 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipykernel) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipykernel) (9.11.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipykernel) (7.2.2)
# Requirement already satisfied: argon2-cffi-bindings in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (25.1.0)
# Requirement already satisfied: colorama>=0.4.4 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel) (0.8.6)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (0.30.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (4.9.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (6.0.3)
# Requirement already satisfied: rfc3339-validator in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: fqdn in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: isoduration in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.1.0)
# Requirement already satisfied: uri-template in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (6.3.0)
# Requirement already satisfied: defusedxml in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: webencodings in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.21.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook) (2.6.3)
# Requirement already satisfied: lark>=1.2.2 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.1)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure-eval in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (0.2.3)
# Requirement already satisfied: cffi>=2.0.0b1 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from cffi>=2.0.0b1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.15.0)
# Requirement already satisfied: arrow>=0.15.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.4.0)
# Requirement already satisfied: tzdata in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (2025.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (26.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pandas
# %pip install numpy
# %pip install seaborn
# %pip install scikit-learn
# %pip install pickle-mixin
# %pip install Flask
# %pip install matplotlib
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import train_test_split, RandomizedSearchCV

from sklearn.preprocessing import OneHotEncoder

from sklearn.metrics import classification_report,confusion_matrix, f1_score

from sklearn.linear_model import LogisticRegression

from sklearn.ensemble import GradientBoostingClassifier

from sklearn.tree import DecisionTreeClassifier
# Out:
# Requirement already satisfied: pandas in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.0.1)
# Requirement already satisfied: numpy>=2.3.3 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (2.4.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from seaborn) (2.4.3)
# Requirement already satisfied: pandas>=1.2 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from seaborn) (3.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (2.4.3)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pickle-mixin in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (1.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: Flask in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.1.3)
# Requirement already satisfied: blinker>=1.9.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from Flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from Flask) (8.3.2)
# Requirement already satisfied: itsdangerous>=2.2.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from Flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from Flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from Flask) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from Flask) (3.1.8)
# Requirement already satisfied: colorama in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from click>=8.1.3->Flask) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **Read The Dataset**

# %%
csv_path = "./application_record.csv"  # update with actual file name
app = pd.read_csv(csv_path)
app.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0        Civil marriage   Rented apartment      -12005          -4542
# 1        Civil marriage   Rented apartment      -12005          -4542
# 2               Married  House / apartment      -21474          -1134
# 3  Single / not married  House / apartment      -19110          -3051
# 4  Single / not married  House / apartment      -19110          -3051
#
#    FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0           1                1           0           0             NaN
# 1           1                1           0           0             NaN
# 2           1                0           0           0  Security staff
# 3           1                0           1           1     Sales staff
# 4           1                0           1           1     Sales staff
#
#    CNT_FAM_MEMBERS
# 0              2.0
# 1              2.0
# 2              2.0
# 3              1.0
# 4              1.0

# %%
csv_path2="./credit_record.csv"
credit=pd.read_csv(csv_path2)
credit.head()
# Out:
#         ID  MONTHS_BALANCE STATUS
# 0  5001711               0      X
# 1  5001711              -1      0
# 2  5001711              -2      0
# 3  5001711              -3      0
# 4  5001712               0      C

# %% [markdown]
# **Univariate Analysis**

# %%
print("Number of people working status:")

print(app['OCCUPATION_TYPE'].value_counts())

sns.set(rc={'figure.figsize': (18,6)})

sns.countplot(x='OCCUPATION_TYPE', data=app, palette='Set2')
# Out:
# Number of people working status:
# OCCUPATION_TYPE
# Laborers                 78240
# Core staff               43007
# Sales staff              41098
# Managers                 35487
# Drivers                  26090
# High skill tech staff    17289
# Accountants              15985
# Medicine staff           13520
# Cooking staff             8076
# Security staff            7993
# Cleaning staff            5845
# Private service staff     3456
# Low-skill Laborers        2140
# Secretaries               2044
# Waiters/barmen staff      1665
# Realty agents             1041
# HR staff                   774
# IT staff                   604
# Name: count, dtype: int64
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6920\356461762.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='OCCUPATION_TYPE', data=app, palette='Set2')
# <Axes: xlabel='OCCUPATION_TYPE', ylabel='count'>

# %%
print("Types of house of the peoples:")

print(app['NAME_HOUSING_TYPE'].value_counts())

sns.set(rc = {'figure.figsize': (15,4)})

sns.countplot(x='NAME_HOUSING_TYPE', data=app, palette='Set2')
# Out:
# Types of house of the peoples:
# NAME_HOUSING_TYPE
# House / apartment      393831
# With parents            19077
# Municipal apartment     14214
# Rented apartment         5974
# Office apartment         3922
# Co-op apartment          1539
# Name: count, dtype: int64
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6920\1034458762.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='NAME_HOUSING_TYPE', data=app, palette='Set2')
# <Axes: xlabel='NAME_HOUSING_TYPE', ylabel='count'>

# %%
print("Income Types Of the Person :")

print(app['NAME_INCOME_TYPE'].value_counts())

sns.set(rc= {'figure.figsize':(8,5)})

sns.countplot(x='NAME_INCOME_TYPE', data=app, palette = 'Set2')
# Out:
# Income Types Of the Person :
# NAME_INCOME_TYPE
# Working                 226104
# Commercial associate    100757
# Pensioner                75493
# State servant            36186
# Student                     17
# Name: count, dtype: int64
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6920\3442218026.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='NAME_INCOME_TYPE', data=app, palette = 'Set2')
# <Axes: xlabel='NAME_INCOME_TYPE', ylabel='count'>

# %% [markdown]
# **Bivariate Analysis**

# %%
credit['default'] = credit['STATUS'].isin(['2', '3', '4', '5'])

# Step 2: Group by ID, mark if any default
default_status = credit.groupby('ID')['default'].max().reset_index()
default_status['Approved'] = default_status['default'].apply(lambda x: 0 if x else 1)
default_status.drop(columns='default', inplace=True)

# Step 3: Merge with application data
app = app.merge(default_status, on='ID', how='inner')
numeric = ['AMT_INCOME_TOTAL', 'CNT_CHILDREN', 'CNT_FAM_MEMBERS', 'DAYS_BIRTH', 'DAYS_EMPLOYED']

for col in numeric:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x='Approved', y=col, data=app)
    plt.title(f'{col} vs Approval Status')
    plt.show()

# %% [markdown]
# **Multivariate Analysis**

# %%
# Select only numerical columns before calculating the correlation
numerical_app = app.select_dtypes(include=np.number)

fig, ax = plt.subplots(figsize=(8,6))

# Calculate and plot the correlation matrix for numerical columns
sns.heatmap(numerical_app.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# **Descriptive Analysis**

# %%
app.describe()
# Out:
#                  ID  CNT_CHILDREN  AMT_INCOME_TOTAL    DAYS_BIRTH  \
# count  3.645700e+04  36457.000000      3.645700e+04  36457.000000
# mean   5.078227e+06      0.430315      1.866857e+05 -15975.173382
# std    4.187524e+04      0.742367      1.017892e+05   4200.549944
# min    5.008804e+06      0.000000      2.700000e+04 -25152.000000
# 25%    5.042028e+06      0.000000      1.215000e+05 -19438.000000
# 50%    5.074614e+06      0.000000      1.575000e+05 -15563.000000
# 75%    5.115396e+06      1.000000      2.250000e+05 -12462.000000
# max    5.150487e+06     19.000000      1.575000e+06  -7489.000000
#
#        DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE    FLAG_PHONE    FLAG_EMAIL  \
# count   36457.000000     36457.0     36457.000000  36457.000000  36457.000000
# mean    59262.935568         1.0         0.225526      0.294813      0.089722
# std    137651.334859         0.0         0.417934      0.455965      0.285787
# min    -15713.000000         1.0         0.000000      0.000000      0.000000
# 25%     -3153.000000         1.0         0.000000      0.000000      0.000000
# 50%     -1552.000000         1.0         0.000000      0.000000      0.000000
# 75%      -408.000000         1.0         0.000000      1.000000      0.000000
# max    365243.000000         1.0         1.000000      1.000000      1.000000
#
#        CNT_FAM_MEMBERS      Approved
# count     36457.000000  36457.000000
# mean          2.198453      0.983103
# std           0.911686      0.128886
# min           1.000000      0.000000
# 25%           2.000000      1.000000
# 50%           2.000000      1.000000
# 75%           3.000000      1.000000
# max          20.000000      1.000000

# %% [markdown]
# ## **Data Pre-Processing**

# %%
app.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 36457 entries, 0 to 36456
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   36457 non-null  int64
#  1   CODE_GENDER          36457 non-null  str
#  2   FLAG_OWN_CAR         36457 non-null  str
#  3   FLAG_OWN_REALTY      36457 non-null  str
#  4   CNT_CHILDREN         36457 non-null  int64
#  5   AMT_INCOME_TOTAL     36457 non-null  float64
#  6   NAME_INCOME_TYPE     36457 non-null  str
#  7   NAME_EDUCATION_TYPE  36457 non-null  str
#  8   NAME_FAMILY_STATUS   36457 non-null  str
#  9   NAME_HOUSING_TYPE    36457 non-null  str
#  10  DAYS_BIRTH           36457 non-null  int64
#  11  DAYS_EMPLOYED        36457 non-null  int64
#  12  FLAG_MOBIL           36457 non-null  int64
#  13  FLAG_WORK_PHONE      36457 non-null  int64
#  14  FLAG_PHONE           36457 non-null  int64
#  15  FLAG_EMAIL           36457 non-null  int64
#  16  OCCUPATION_TYPE      25134 non-null  str
#  17  CNT_FAM_MEMBERS      36457 non-null  float64
#  18  Approved             36457 non-null  int64
# dtypes: float64(2), int64(9), str(8)
# memory usage: 5.3 MB

# %%
def unique_values():

  a=app.CODE_GENDER.unique()

  print("----------------CODE GENDER-------------------")

  print(a)

  print()

  b=app.FLAG_OWN_CAR.unique()

  print("------------------FLAG OWN CAR----------------")

  print(b)

  print()

  c=app.FLAG_OWN_REALTY.unique()

  print("----------------FLAG OWN REALTY----------------")

  print(c)

  print()

  d=app.CNT_CHILDREN.unique()

  print("---------------- CNT_CHILDREN------------------")

  print(d)

  print()

  e=app.NAME_INCOME_TYPE.unique()

  print("----------------NAME INCOME TYPE----------------")

  print(e)

  print()

  f=app.NAME_EDUCATION_TYPE.unique()

  print("----------------NAME EDUCATION TYPE--------------")

  print(f)

  print()
  g=app.NAME_FAMILY_STATUS.unique()

  print("----------------NAME FAMILY STATUS----------------")

  print(g)

  print()

  h=app.NAME_HOUSING_TYPE.unique()

  print("----------------NAME HOUSING TYPE----------------")

  print(h)

  print()

  i=app.OCCUPATION_TYPE.unique()

  print("----------------OCCUPATION TYPE------------------")

  print(i)

  print()

  j=app.CNT_FAM_MEMBERS.unique()

  print("----------------CNT FAM MEMBERS------------------")

  print(j)

  print()

  return unique_values

# %% [markdown]
# **Dropping Unwanted Features**

# %%
app.drop_duplicates (subset=['CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'FLAG_MOBIL', 'FLAG_WORK_PHONE', 'FLAG_PHONE', 'FLAG_EMAIL', 'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS'], keep='first', inplace=True)

# %% [markdown]
# **Handling Missing Values**

# %%
app.isnull().mean()
# Out:
# ID                     0.000000
# CODE_GENDER            0.000000
# FLAG_OWN_CAR           0.000000
# FLAG_OWN_REALTY        0.000000
# CNT_CHILDREN           0.000000
# AMT_INCOME_TOTAL       0.000000
# NAME_INCOME_TYPE       0.000000
# NAME_EDUCATION_TYPE    0.000000
# NAME_FAMILY_STATUS     0.000000
# NAME_HOUSING_TYPE      0.000000
# DAYS_BIRTH             0.000000
# DAYS_EMPLOYED          0.000000
# FLAG_MOBIL             0.000000
# FLAG_WORK_PHONE        0.000000
# FLAG_PHONE             0.000000
# FLAG_EMAIL             0.000000
# OCCUPATION_TYPE        0.308491
# CNT_FAM_MEMBERS        0.000000
# Approved               0.000000
# dtype: float64

# %% [markdown]
# **Data Cleaning And Merging**

# %%
def data_cleansing(data):
    # Adding number of family members with number of children to get overall family members.
    #data['CNT_FAM_MEMBERS'] = data['CNT_FAM_MEMBERS'] + data['CNT_CHILDREN']

    dropped_cols = ['FLAG_MOBIL', 'FLAG_WORK_PHONE', 'FLAG_PHONE',
                    'FLAG_EMAIL', 'OCCUPATION_TYPE', 'CNT_CHILDREN']
    data = data.drop(dropped_cols, axis = 1)

    #converting birth years and days employed to years.
    data['DAYS_BIRTH'] = np.abs(data['DAYS_BIRTH'])/365 #Absolute
    data['DAYS_EMPLOYED'] = data['DAYS_EMPLOYED']/365

    #Cleaning up categorical values to lower the count of dummy variables.
    housing_type = {'House / apartment' : 'House / apartment',
                    'With parents': 'With parents',
                    'Municipal apartment' : 'House / apartment',
                    'Rented apartment' : 'House / apartment',
                    'Office apartment' : 'House / apartment',
                    'Co-op apartment' : 'House / apartment'}

    income_type = {'Commercial associate':'Working',
                   'State servant':'Working',
                   'Working':'Working',
                   'Pensioner':'Pensioner',
                   'Student':'Student'}

    education_type = {'Secondary / secondary special':'secondary',
                      'Lower secondary':'secondary',
                      'Higher education':'Higher education',
                      'Incomplete higher':'Higher education',
                      'Academic degree':'Academic degree'}

    family_status = {'Single / not married':'Single',
                     'Separated':'Single',
                     'Widow':'Single',
                     'Civil marriage':'Married',
                     'Married':'Married'}

    data['NAME_HOUSING_TYPE'] = data['NAME_HOUSING_TYPE'].map(housing_type)
    data['NAME_INCOME_TYPE'] = data['NAME_INCOME_TYPE'].map(income_type)
    data['NAME_EDUCATION_TYPE']=data['NAME_EDUCATION_TYPE'].map(education_type)
    data['NAME_FAMILY_STATUS']=data['NAME_FAMILY_STATUS'].map(family_status)

    return data
data = data_cleansing(app)
data.head()
# Out:
#          ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  AMT_INCOME_TOTAL  \
# 0   5008804           M            Y               Y          427500.0
# 2   5008806           M            Y               Y          112500.0
# 3   5008808           F            N               Y          270000.0
# 7   5008812           F            N               Y          283500.0
# 10  5008815           M            Y               Y          270000.0
#
#    NAME_INCOME_TYPE NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  \
# 0           Working    Higher education            Married  House / apartment
# 2           Working           secondary            Married  House / apartment
# 3           Working           secondary             Single  House / apartment
# 7         Pensioner    Higher education             Single  House / apartment
# 10          Working    Higher education            Married  House / apartment
#
#     DAYS_BIRTH  DAYS_EMPLOYED  CNT_FAM_MEMBERS  Approved
# 0    32.890411     -12.443836              2.0         1
# 2    58.832877      -3.106849              2.0         1
# 3    52.356164      -8.358904              1.0         1
# 7    61.545205    1000.665753              1.0         1
# 10   46.224658      -2.106849              2.0         1

# %%
def handle_outliers(data):
    # Define the columns to check for outliers (numerical only)
    num_cols = ['AMT_INCOME_TOTAL', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'CNT_FAM_MEMBERS']

    for col in num_cols:
        Q1 = data[col].quantile(0.25)
        Q3 = data[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Keep only rows within the IQR range
        data = data[(data[col] >= lower_bound) & (data[col] <= upper_bound)]

    return data
handle_outliers(app)
# Out:
#             ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 2      5008806           M            Y               Y             0
# 3      5008808           F            N               Y             0
# 10     5008815           M            Y               Y             0
# 12     5008819           M            Y               Y             0
# 18     5008825           F            Y               N             0
# ...        ...         ...          ...             ...           ...
# 36441  5148694           F            N               N             0
# 36445  5149055           F            N               Y             0
# 36450  5149729           M            Y               Y             0
# 36454  5149838           F            N               Y             0
# 36456  5150337           M            N               Y             0
#
#        AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 2              112500.0               Working  Secondary / secondary special
# 3              270000.0  Commercial associate  Secondary / secondary special
# 10             270000.0               Working               Higher education
# 12             135000.0  Commercial associate  Secondary / secondary special
# 18             130500.0               Working              Incomplete higher
# ...                 ...                   ...                            ...
# 36441          180000.0             Pensioner  Secondary / secondary special
# 36445          112500.0  Commercial associate  Secondary / secondary special
# 36450           90000.0               Working  Secondary / secondary special
# 36454          157500.0             Pensioner               Higher education
# 36456          112500.0               Working  Secondary / secondary special
#
#          NAME_FAMILY_STATUS    NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 2                   Married    House / apartment      -21474          -1134
# 3      Single / not married    House / apartment      -19110          -3051
# 10                  Married    House / apartment      -16872           -769
# 12                  Married    House / apartment      -17778          -1194
# 18                  Married    House / apartment      -10669          -1103
# ...                     ...                  ...         ...            ...
# 36441        Civil marriage  Municipal apartment      -20600           -198
# 36445               Married    House / apartment      -15837          -2694
# 36450               Married    House / apartment      -19101          -1721
# 36454               Married    House / apartment      -12387          -1325
# 36456  Single / not married     Rented apartment       -9188          -1193
#
#        FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 2               1                0           0           0  Security staff
# 3               1                0           1           1     Sales staff
# 10              1                1           1           1     Accountants
# 12              1                0           0           0        Laborers
# 18              1                0           0           0     Accountants
# ...           ...              ...         ...         ...             ...
# 36441           1                0           0           0        Laborers
# 36445           1                1           1           0             NaN
# 36450           1                0           0           0             NaN
# 36454           1                0           1           1  Medicine staff
# 36456           1                0           0           0        Laborers
#
#        CNT_FAM_MEMBERS  Approved
# 2                  2.0         1
# 3                  1.0         1
# 10                 2.0         1
# 12                 2.0         1
# 18                 2.0         1
# ...                ...       ...
# 36441              2.0         0
# 36445              2.0         0
# 36450              2.0         0
# 36454              2.0         0
# 36456              1.0         0
#
# [7145 rows x 19 columns]

# %%
credit.head()
# Out:
#         ID  MONTHS_BALANCE STATUS  default
# 0  5001711               0      X    False
# 1  5001711              -1      0    False
# 2  5001711              -2      0    False
# 3  5001711              -3      0    False
# 4  5001712               0      C    False

# %%
# Data frame to analyze length of time since initial approval of credit card
# Shows number of past dues, paid off and no loan status.
grouped = credit.groupby('ID')

pivot_tb = credit.pivot(index = 'ID', columns = 'MONTHS_BALANCE', values = 'STATUS')
pivot_tb['open_month'] = grouped['MONTHS_BALANCE'].min()
pivot_tb['end_month'] = grouped['MONTHS_BALANCE'].max()
pivot_tb['window'] = pivot_tb['end_month'] - pivot_tb['open_month']
pivot_tb['window'] += 1 # Adding 1 since month starts at 0.

#Counting number of past dues, paid offs and no loans.
pivot_tb['paid_off'] = pivot_tb[pivot_tb.iloc[:,0:61] == 'C'].count(axis = 1)
pivot_tb['pastdue_1-29'] = pivot_tb[pivot_tb.iloc[:,0:61] == '0'].count(axis = 1)
pivot_tb['pastdue_30-59'] = pivot_tb[pivot_tb.iloc[:,0:61] == '1'].count(axis = 1)
pivot_tb['pastdue_60-89'] = pivot_tb[pivot_tb.iloc[:,0:61] == '2'].count(axis = 1)
pivot_tb['pastdue_90-119'] = pivot_tb[pivot_tb.iloc[:,0:61] == '3'].count(axis = 1)
pivot_tb['pastdue_120-149'] = pivot_tb[pivot_tb.iloc[:,0:61] == '4'].count(axis = 1)
pivot_tb['pastdue_over_150'] = pivot_tb[pivot_tb.iloc[:,0:61] == '5'].count(axis = 1)
pivot_tb['no_loan'] = pivot_tb[pivot_tb.iloc[:,0:61] == 'X'].count(axis = 1)

#Setting Id column to merge with app data.
pivot_tb['ID'] = pivot_tb.index

# %%
pivot_tb.head()
# Out:
# MONTHS_BALANCE  -60  -59  -58  -57  -56  -55  -54  -53  -52  -51  ... window  \
# ID                                                                ...
# 5001711         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...      4
# 5001712         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...     19
# 5001713         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...     22
# 5001714         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...     15
# 5001715         NaN    X    X    X    X    X    X    X    X    X  ...     60
#
# MONTHS_BALANCE paid_off pastdue_1-29 pastdue_30-59 pastdue_60-89  \
# ID
# 5001711               0            3             0             0
# 5001712               9           10             0             0
# 5001713               0            0             0             0
# 5001714               0            0             0             0
# 5001715               0            0             0             0
#
# MONTHS_BALANCE pastdue_90-119 pastdue_120-149 pastdue_over_150 no_loan  \
# ID
# 5001711                     0               0                0       1
# 5001712                     0               0                0       0
# 5001713                     0               0                0      22
# 5001714                     0               0                0      15
# 5001715                     0               0                0      60
#
# MONTHS_BALANCE       ID
# ID
# 5001711         5001711
# 5001712         5001712
# 5001713         5001713
# 5001714         5001714
# 5001715         5001715
#
# [5 rows x 73 columns]

# %% [markdown]
# **Feature Engineering**

# %%
def feature_engineering_target(data):
    good_or_bad = []

    for index, row in data.iterrows():
        paid_off = row['paid_off']
        over_1 = row['pastdue_1-29']
        over_30 = row['pastdue_30-59']
        over_60 = row['pastdue_60-89']
        over_90 = row['pastdue_90-119']
        over_120 = row['pastdue_120-149'] + row['pastdue_over_150']
        no_loan = row['no_loan']

        overall_pastdues = over_1 + over_30 + over_60 + over_90 + over_120

        if overall_pastdues == 0:
            if paid_off >= no_loan or paid_off <= no_loan:
                good_or_bad.append(1)
            elif paid_off == 0 and no_loan == 1:
                good_or_bad.append(1)

        elif overall_pastdues != 0:
            if paid_off > overall_pastdues:
                good_or_bad.append(1)
            elif paid_off <= overall_pastdues:
                good_or_bad.append(0)

        elif paid_off == 0 and no_loan != 0:
            if overall_pastdues <= no_loan or overall_pastdues >= no_loan:
                good_or_bad.append(0)
        else:
            good_or_bad.append(1)

    return good_or_bad

# %%
target = pd.DataFrame()
target['ID'] = pivot_tb.index
target['paid_off'] = pivot_tb['paid_off'].values
target['#_of_pastdues'] = pivot_tb['pastdue_1-29'].values + pivot_tb['pastdue_30-59'].values \
+ pivot_tb['pastdue_60-89'].values + pivot_tb['pastdue_90-119'].values \
+ pivot_tb['pastdue_120-149'].values + pivot_tb['pastdue_over_150'].values

target['no_loan'] = pivot_tb['no_loan'].values
target['target'] = feature_engineering_target(pivot_tb)
credit_app = data_cleansing(app).merge(target, how = 'inner', on = 'ID')
credit_app.drop('ID', axis = 1, inplace = True)

credit_app
# Out:
#      CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  AMT_INCOME_TOTAL  \
# 0              M            Y               Y          427500.0
# 1              M            Y               Y          112500.0
# 2              F            N               Y          270000.0
# 3              F            N               Y          283500.0
# 4              M            Y               Y          270000.0
# ...          ...          ...             ...               ...
# 9723           F            N               N          180000.0
# 9724           F            N               Y          112500.0
# 9725           M            Y               Y           90000.0
# 9726           F            N               Y          157500.0
# 9727           M            N               Y          112500.0
#
#      NAME_INCOME_TYPE NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# 0             Working    Higher education            Married
# 1             Working           secondary            Married
# 2             Working           secondary             Single
# 3           Pensioner    Higher education             Single
# 4             Working    Higher education            Married
# ...               ...                 ...                ...
# 9723        Pensioner           secondary            Married
# 9724          Working           secondary            Married
# 9725          Working           secondary            Married
# 9726        Pensioner    Higher education            Married
# 9727          Working           secondary             Single
#
#       NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  CNT_FAM_MEMBERS  Approved  \
# 0     House / apartment   32.890411     -12.443836              2.0         1
# 1     House / apartment   58.832877      -3.106849              2.0         1
# 2     House / apartment   52.356164      -8.358904              1.0         1
# 3     House / apartment   61.545205    1000.665753              1.0         1
# 4     House / apartment   46.224658      -2.106849              2.0         1
# ...                 ...         ...            ...              ...       ...
# 9723  House / apartment   56.438356      -0.542466              2.0         0
# 9724  House / apartment   43.389041      -7.380822              2.0         0
# 9725  House / apartment   52.331507      -4.715068              2.0         0
# 9726  House / apartment   33.936986      -3.630137              2.0         0
# 9727  House / apartment   25.172603      -3.268493              1.0         0
#
#       paid_off  #_of_pastdues  no_loan  target
# 0           13              2        1       1
# 1            7              7       16       0
# 2            0              2        3       0
# 3            0             14        3       0
# 4            0              6        0       0
# ...        ...            ...      ...     ...
# 9723         0             21        0       0
# 9724         8             12        0       0
# 9725         0             17        5       0
# 9726        14             19        0       0
# 9727         0             14        0       0
#
# [9728 rows x 16 columns]

# %%
from sklearn.preprocessing import LabelEncoder

cg = LabelEncoder()
oc = LabelEncoder()
own_r = LabelEncoder()
it = LabelEncoder()
et = LabelEncoder()
fs = LabelEncoder()
ht = LabelEncoder()

credit_app['CODE_GENDER'] = cg.fit_transform(credit_app['CODE_GENDER'])
credit_app['FLAG_OWN_CAR'] = oc.fit_transform(credit_app['FLAG_OWN_CAR'])
credit_app['FLAG_OWN_REALTY'] = own_r.fit_transform(credit_app['FLAG_OWN_REALTY'])
credit_app['NAME_INCOME_TYPE'] = it.fit_transform(credit_app['NAME_INCOME_TYPE'])
credit_app['NAME_EDUCATION_TYPE'] = et.fit_transform(credit_app['NAME_EDUCATION_TYPE'])
credit_app['NAME_FAMILY_STATUS'] = fs.fit_transform(credit_app['NAME_FAMILY_STATUS'])
credit_app['NAME_HOUSING_TYPE'] = ht.fit_transform(credit_app['NAME_HOUSING_TYPE'])


credit_app
# Out:
#       CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  AMT_INCOME_TOTAL  \
# 0               1             1                1          427500.0
# 1               1             1                1          112500.0
# 2               0             0                1          270000.0
# 3               0             0                1          283500.0
# 4               1             1                1          270000.0
# ...           ...           ...              ...               ...
# 9723            0             0                0          180000.0
# 9724            0             0                1          112500.0
# 9725            1             1                1           90000.0
# 9726            0             0                1          157500.0
# 9727            1             0                1          112500.0
#
#       NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  NAME_FAMILY_STATUS  \
# 0                    2                    1                   0
# 1                    2                    2                   0
# 2                    2                    2                   1
# 3                    0                    1                   1
# 4                    2                    1                   0
# ...                ...                  ...                 ...
# 9723                 0                    2                   0
# 9724                 2                    2                   0
# 9725                 2                    2                   0
# 9726                 0                    1                   0
# 9727                 2                    2                   1
#
#       NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  CNT_FAM_MEMBERS  Approved  \
# 0                     0   32.890411     -12.443836              2.0         1
# 1                     0   58.832877      -3.106849              2.0         1
# 2                     0   52.356164      -8.358904              1.0         1
# 3                     0   61.545205    1000.665753              1.0         1
# 4                     0   46.224658      -2.106849              2.0         1
# ...                 ...         ...            ...              ...       ...
# 9723                  0   56.438356      -0.542466              2.0         0
# 9724                  0   43.389041      -7.380822              2.0         0
# 9725                  0   52.331507      -4.715068              2.0         0
# 9726                  0   33.936986      -3.630137              2.0         0
# 9727                  0   25.172603      -3.268493              1.0         0
#
#       paid_off  #_of_pastdues  no_loan  target
# 0           13              2        1       1
# 1            7              7       16       0
# 2            0              2        3       0
# 3            0             14        3       0
# 4            0              6        0       0
# ...        ...            ...      ...     ...
# 9723         0             21        0       0
# 9724         8             12        0       0
# 9725         0             17        5       0
# 9726        14             19        0       0
# 9727         0             14        0       0
#
# [9728 rows x 16 columns]

# %% [markdown]
# **Splitting Data Into Train and Test Set**

# %%
xtrain, xtest, ytrain, ytest = train_test_split(
    credit_app.drop(['target', 'Approved'], axis=1),
    credit_app['target'],
    test_size=0.2,
    random_state=0
)

# %% [markdown]
# ## **Model Building**

# %% [markdown]
# **Logistic Regression Model**

# %%
def logistic_reg(xtrain, xtest, ytrain, ytest):
    lr = LogisticRegression(solver='liblinear')
    lr.fit(xtrain, ytrain)
    ypred = lr.predict(xtest)
    print("LogisticRegression")
    print('Confusion matrix')
    print(confusion_matrix(ytest, ypred))
    print('Classification report')
    print(classification_report(ytest, ypred))
    return lr

# %% [markdown]
# **Random Forest Classifier**

# %%
def random_forest(xtrain, xtest, ytrain, ytest):
    rf = RandomForestClassifier()
    rf.fit(xtrain, ytrain)
    ypred = rf.predict(xtest)
    print("RandomForestClassifier")
    print('Confusion matrix')
    print(confusion_matrix(ytest, ypred))
    print('Classification report')
    print(classification_report(ytest, ypred))

# %% [markdown]
# **XG Boost Model**

# %%
def g_boosting(xtrain, xtest, ytrain, ytest):
    gb = GradientBoostingClassifier()
    gb.fit(xtrain, ytrain)
    ypred = gb.predict(xtest)
    print("GradientBoostingClassifier")
    print('Confusion matrix')
    print(confusion_matrix(ytest, ypred))
    print('Classification report')
    print(classification_report(ytest, ypred))

# %% [markdown]
# **Decision Tree Model**

# %%
def d_tree(xtrain, xtest, ytrain, ytest):
    dt = DecisionTreeClassifier()
    dt.fit(xtrain, ytrain)
    ypred = dt.predict(xtest)
    print("DecisionTreeClassifier")
    print('Confusion matrix')
    print(confusion_matrix(ytest, ypred))
    print('Classification report')
    print(classification_report(ytest, ypred))

# %% [markdown]
# **Comparision Of Models**

# %%
def compare_model(xtrain,xtest,ytrain,ytest):
    logistic_reg(xtrain, xtest, ytrain, ytest)
    print('-'*100)
    random_forest(xtrain, xtest, ytrain, ytest)
    print('-'*100)
    g_boosting(xtrain, xtest, ytrain, ytest)
    print('-'*100)
    d_tree(xtrain, xtest, ytrain, ytest)
compare_model(xtrain,xtest,ytrain,ytest)
# Out:
# LogisticRegression
# Confusion matrix
# [[1049   15]
#  [   3  879]]
# Classification report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      1064
#            1       0.98      1.00      0.99       882
#
#     accuracy                           0.99      1946
#    macro avg       0.99      0.99      0.99      1946
# weighted avg       0.99      0.99      0.99      1946
#
# ----------------------------------------------------------------------------------------------------
# RandomForestClassifier
# Confusion matrix
# [[1045   19]
#  [  13  869]]
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98      1064
#            1       0.98      0.99      0.98       882
#
#     accuracy                           0.98      1946
#    macro avg       0.98      0.98      0.98      1946
# weighted avg       0.98      0.98      0.98      1946
#
# ----------------------------------------------------------------------------------------------------
# GradientBoostingClassifier
# Confusion matrix
# [[1061    3]
#  [   2  880]]
# Classification report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1064
#            1       1.00      1.00      1.00       882
#
#     accuracy                           1.00      1946
#    macro avg       1.00      1.00      1.00      1946
# weighted avg       1.00      1.00      1.00      1946
#
# ----------------------------------------------------------------------------------------------------
# DecisionTreeClassifier
# Confusion matrix
# [[1062    2]
#  [   2  880]]
# Classification report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1064
#            1       1.00      1.00      1.00       882
#
#     accuracy                           1.00      1946
#    macro avg       1.00      1.00      1.00      1946
# weighted avg       1.00      1.00      1.00      1946

# %% [markdown]
# **Saving The Model**

# %%
import pickle
import os
from sklearn.tree import DecisionTreeClassifier

# Train your model
dt = DecisionTreeClassifier()
dt.fit(xtrain, ytrain)

# Create model/ directory if it doesn't exist
os.makedirs('model', exist_ok=True)

# Save the model
with open('model/c_card_approval_pred.pickle', 'wb') as f:
    pickle.dump(dt, f)
